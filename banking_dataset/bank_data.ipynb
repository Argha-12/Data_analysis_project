# %%
import pandas as pd

df = pd.read_csv("Comprehensive_Banking_Database.csv")
df.head(5)
# df.isna()
# Out:
#    Customer ID First Name Last Name  Age  Gender    Address           City  \
# 0            1     Joshua      Hall   45    Male  Address_1     Fort Worth
# 1            2       Mark    Taylor   47  Female  Address_2     Louisville
# 2            3     Joseph    Flores   25  Female  Address_3   Philadelphia
# 3            4      Kevin       Lee   52   Other  Address_4  Oklahoma City
# 4            5      Linda   Johnson   68   Other  Address_5        Phoenix
#
#    Contact Number                  Email Account Type  ...  \
# 0     19458794854    joshua.hall@kag.com      Current  ...
# 1     19458794855    mark.taylor@kag.com      Current  ...
# 2     19458794856  joseph.flores@kag.com      Current  ...
# 3     19458794857      kevin.lee@kag.com      Savings  ...
# 4     19458794858  linda.johnson@kag.com      Savings  ...
#
#    Credit Card Balance Minimum Payment Due Payment Due Date  \
# 0              4524.32              226.22       11/26/2023
# ...

# %%
# What are the most common types of transactions (e.g., withdrawals, deposits, transfers)
# Count occurrences of each transaction type


transaction_counts = df['Transaction Type'].value_counts()

# Convert the result to a DataFrame for better display
transaction_counts_df = transaction_counts.reset_index()
transaction_counts_df.columns = ['transaction_type', 'count']
transaction_counts_df = transaction_counts_df.sort_values(by='count', ascending=False)

print(transaction_counts_df)
# Out:
#   transaction_type  count
# 0          Deposit   1698
# 1       Withdrawal   1673
# 2         Transfer   1629

# %%
# Who are the top 10 customers with the highest account balances

top_10_customers = df.nlargest(10 , 'Account Balance')

top_10_customers.head(10)

# print(top_10_customers['First Name', 'Account Balance'])

# What are the top 10 customers with the highest average transaction amounts
# Out:
#       Customer ID First Name Last Name  Age  Gender       Address  \
# 4055         4056       Mark    Flores   46    Male  Address_4056
# 3881         3882     Andrew     Moore   32    Male  Address_3882
# 292           293    Michael    Carter   46   Other   Address_293
# 370           371     Andrew     Smith   22   Other   Address_371
# 4983         4984    Barbara    Garcia   47   Other  Address_4984
# 4030         4031   Kimberly      King   22   Other  Address_4031
# 2253         2254      Betty  Campbell   67   Other  Address_2254
# 27             28     Amanda      Hill   60  Female    Address_28
# 2958         2959       Mary    Miller   57  Female  Address_2959
# 959           960    Matthew  Campbell   25   Other   Address_960
#
#                City  Contact Number                     Email Account Type  \
# 4055       San Jose     19458798909       mark.flores@kag.com      Savings
# 3881         Denver     19458798735      andrew.moore@kag.com      Current
# ...
